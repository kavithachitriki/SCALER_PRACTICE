# %% [markdown]
# <a href="https://colab.research.google.com/github/kavithachitriki/SCALER_PRACTICE/blob/main/seaborn_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')

# %%
type(iris)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
iris["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
sns.histplot(iris["petal_length"],bins=10)

# %%
sns.histplot(iris["petal_length"],bins=20)

# %%
sns.kdeplot(iris["petal_length"])

# %%
sns.boxplot(y=iris["petal_length"])

# %%
iris["petal_length"].max()
# Out:
# 6.9

# %%
iris["petal_length"].min()
# Out:
# 1.0

# %%
sns.countplot(x="species",data=iris)

# %%
n_s=iris[iris["species"] == "setosa"].shape[0]
n_v=iris[iris["species"] == "versicolor"].shape[0]
n_vi=iris[iris["species"] == "virginica"].shape[0]

# %%
plt.pie([n_s,n_v,n_vi],labels=["setosa","versicolor","virginica"],autopct="%.0f%%")
plt.show()

# %%
sns.scatterplot(x=iris["petal_length"],y=iris["petal_width"])

# %%
sns.jointplot(x=iris["petal_length"],y=iris["petal_width"])

# %%
sns.jointplot(x=iris["petal_length"],y=iris["petal_width"],kind="reg")

# %%
sns.pairplot(data=iris,corner=True)

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(),annot=True)

# %%
sns.heatmap(iris.corr(),cmap="Blues", annot=True)

# %%
sns.lineplot(x=iris['petal_length'],y=iris["petal_width"])

# %%
sns.boxplot(x="species",y="sepal_length",data=iris)

# %%
sns.kdeplot(x="sepal_length",data=iris,hue="species")

# %%
sns.barplot(x="species",y="sepal_length",data=iris,estimator=np.mean)

# %%
sns.violinplot(x="species",y="sepal_length",data=iris,estimator=np.mean)

# %%
sns.countplot(x=tips["smoker"])

# %%
sns.countplot(x=tips["smoker"],hue=tips["sex"],dodge=False)

# %%
sns.countplot(x=tips["smoker"],hue=tips["sex"],dodge=True)

# %%
sns.scatterplot(x="total_bill",y="tip",size="size",data=tips)

# %%
sns.scatterplot(x="petal_length",y="petal_width",hue="species",data=iris)

# %%
sns.boxplot(x=tips["smoker"],y=tips["total_bill"],hue=tips["sex"],dodge=True)
